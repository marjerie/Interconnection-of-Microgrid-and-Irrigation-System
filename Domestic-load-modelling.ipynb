# %%
import pandas as pd
import numpy as np
import math
import random
import array
from numpy import zeros

# %%
house_inc = 0
app_inc = 0
inc = 0
s=25
m=0
l=0
healthcare=0
school=2
load_tot = []

# %%
hi=array.array('d',[])
hour0_4=array.array('d',[])
f = open("D:/HI.txt")
for i in f:
    hi.append(float(i[0:6]))
k=0
hiavg=array.array('d',[])
while k<8760:
    dummy=sum(hi[k:k+4])
    hiavg.append(round(dummy/4))
    hiavg.append(round(dummy/4))
    hiavg.append(round(dummy/4))
    hiavg.append(round(dummy/4))
    k+=4

# %%
for year in range (0,20):
    l_fan = []
    l_light = []
    l_bulb = []
    l_tv = []
    l_socket = []
    l_healthfan = []
    l_healthlight = []
    l_schoolfan = []
    l_schoollight = []
    load = []
    healthfan=array.array('d',[])
    healthlight=array.array('d',[])
    schoolfan=array.array('d',[])
    schoollight=array.array('d',[])
    print ('year = ',year)
    print ('small house = ',s)
    print ('medium house = ',m)
    print ('large house = ',l)
    for iteration in range (int(s+m+2*l)):
        bulb = [] 
        i=0
        while i<8760:
            if i%168<24 or i%168>71:
                while i%24<4: #0-3                      
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        bulb.append(hour0_4[p]) 
                    i+=1
                while i%24<8 and i%24>3:     #4-7
                    if hiavg[i]<3:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        for p in range(4):
                            bulb.append(hour0_4[p])
                    if hiavg[i]>2:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=1
                        bulb.append(hour0)
                        bulb.append(hour1)
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour2,hour3]
                        random.shuffle(hour0_4)
                        for p in range(2):
                            bulb.append(hour0_4[p])
                    i+=1  
                while i%24<12 and i%24>7:       #8-11
                    if hiavg[i]==1:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=0
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=0
                        hour1=0
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=1
                    for p in range(4):
                        bulb.append(hour0_4[p])  
                while i%24<16 and i%24>11:            #12-15
                    if hiavg[i]<4:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>3:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=1             
                    for p in range(4):
                        bulb.append(hour0_4[p])  
                while i%24<20 and i%24>15:                 #16-19
                    if hiavg[i]<3:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>2:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1      
                    for p in range(4):
                        bulb.append(hour0_4[p])  
                while i%24<24 and i%24>19:                #20-23
                    if hiavg[i]==1:
                        hour0=1
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>1:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1
                    for p in range(4):
                        bulb.append(hour0_4[p]) 
            else:
                while i%24<4:                  #0-3
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        bulb.append(hour0_4[p]) 
                    i+=1
                while i%24<8 and i%24>3:            #4-7
                    if hiavg[i]<3:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        for p in range(4):
                            bulb.append(hour0_4[p])  
                    if hiavg[i]>2:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=1
                        bulb.append(hour0)
                        bulb.append(hour1)
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour2,hour3]
                        random.shuffle(hour0_4)
                        for p in range(2):
                            bulb.append(hour0_4[p])  
                    i+=1
                while i%24<12 and i%24>7:             #8-11
                    if hiavg[i]==1:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=0
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=0
                        hour1=0
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=1
                    for p in range(4):
                        bulb.append(hour0_4[p])  
                while i%24<16 and i%24>11:                      #12-15
                    if hiavg[i]<4:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>3:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=1             
                    for p in range(4):
                        bulb.append(hour0_4[p])  
                while i%24<20 and i%24>15:                    #16-19
                    if hiavg[i]<3:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>2:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1      
                    for p in range(4):
                        bulb.append(hour0_4[p])  
                while i%24<24 and i%24>19:                  #20-23
                    if hiavg[i]==1:
                        hour0=1
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>1:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1
                    for p in range(4):
                        bulb.append(hour0_4[p])
        if iteration ==0:
            for k in range (0,8760):
                l_bulb.append(bulb[k])
        else:
            for k in range (0,8760):
                l_bulb[k]=l_bulb[k]+bulb[k]

    l_bulb = [i * 0.015 for i in l_bulb]
    
    for iteration in range (int(s+2*m+3*l)):
        fan = []  
        i=0
        while i<8760:
            if i%168<24 or i%168>71:
                while i%24<4:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    for p in range(4):
                        fan.append(hour0_4[p]) 
                    i+=4
                while i%24<8 and i%24>3:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        fan.append(hour0_4[p])  
                while i%24<12 and i%24>7:
                    if hiavg[i]==1 or hiavg[i]==2:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=1
                        hour1=0
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=1
                        hour1=1
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        fan.append(hour0_4[p])  
                while i%24<16 and i%24>11:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2 or hiavg[i]==3:
                        hour0=0
                        hour1=1
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=0
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4             
                    for p in range(4):
                        fan.append(hour0_4[p])  
                while i%24<20 and i%24>15:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4      
                    for p in range(4):
                        fan.append(hour0_4[p])  
                while i%24<24 and i%24>19:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        fan.append(hour0_4[p]) 
            else:
                while i%24<4:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    for p in range(4):
                        fan.append(hour0_4[p]) 
                    i+=4
                while i%24<8 and i%24>3:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        fan.append(hour0_4[p])  
                while i%24<12 and i%24>7:
                    if hiavg[i]==1 or hiavg[i]==2:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=1
                        hour1=math.floor(random.uniform(0,2))
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        fan.append(hour0_4[p])  
                while i%24<16 and i%24>11:
                    if hiavg[i]==1:
                        hour0=1
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2 or hiavg[i]==3:
                        hour0=0
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4             
                    for p in range(4):
                        fan.append(hour0_4[p])  
                while i%24<20 and i%24>15:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4      
                    for p in range(4):
                        fan.append(hour0_4[p])  
                while i%24<24 and i%24>19:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        fan.append(hour0_4[p]) 
        if iteration ==0:
            for k in range (0,8760):
                l_fan.append(fan[k])
        else:
            for k in range (0,8760):
                l_fan[k]=l_fan[k]+fan[k]

    l_fan = [i * 0.075 for i in l_fan]
    
    for iteration in range (int(s+2*m+2*l)):
        light = []
        i=0
        while i<8760:
            if i%168<24 or i%168>71:
                while i%24<4: #0-3
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        light.append(hour0_4[p]) 
                    i+=1
                while i%24<8 and i%24>3:     #4-7
                    if hiavg[i]<3:
                        hour0=0
                        hour1=1
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>2:
                        hour0=0
                        hour1=1
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1
                    for p in range(4):
                        light.append(hour0_4[p])  
                while i%24<12 and i%24>7:       #8-11
                    if hiavg[i]==1:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>3:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=1
                    for p in range(4):
                        light.append(hour0_4[p])  
                while i%24<16 and i%24>11:            #12-15
                    if hiavg[i]==1:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=1             
                    for p in range(4):
                        light.append(hour0_4[p])  
                while i%24<20 and i%24>15:                 #16-19
                    if hiavg[i]<3:
                        hour0=0
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>2:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1      
                    for p in range(4):
                        light.append(hour0_4[p])  
                while i%24<24 and i%24>19:                #20-23
                    if hiavg[i]<3:
                        hour0=1
                        hour1=1
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>2:
                        hour0=1
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1
                    for p in range(4):
                        light.append(hour0_4[p]) 
            else:
                while i%24<4:                  #0-3
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        light.append(hour0_4[p]) 
                    i+=1
                while i%24<8 and i%24>3:            #4-7
                    if hiavg[i]<3:
                        hour0=0
                        hour1=1
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>2:
                        hour0=0
                        hour1=1
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1
                    for p in range(4):
                        light.append(hour0_4[p])  
                while i%24<12 and i%24>7:             #8-11
                    if hiavg[i]==1:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==4:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==5:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=1
                    for p in range(4):
                        light.append(hour0_4[p])  
                while i%24<16 and i%24>11:                      #12-15
                    if hiavg[i]==1:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==3:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>3:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=1             
                    for p in range(4):
                        light.append(hour0_4[p])  
                while i%24<20 and i%24>15:                    #16-19
                    if hiavg[i]<3:
                        hour0=0
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>2:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1      
                    for p in range(4):
                        light.append(hour0_4[p])  
                while i%24<24 and i%24>19:                  #20-23
                    if hiavg[i]<3:
                        hour0=1
                        hour1=1
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    if hiavg[i]>2:
                        hour0=1
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=1
                    for p in range(4):
                        light.append(hour0_4[p])
        if iteration ==0:
            for k in range (0,8760):
                l_light.append(light[k])
        else:
            for k in range (0,8760):
                l_light[k]=l_light[k]+light[k]
                            
    l_light = [i * 0.040 for i in l_light]
                            
    for iteration in range (int(m+l)):
        tv = []
        i=0
        while i<8760:
            if i%168<24 or i%168>71:
                while i%24<7:
                    hour0=0
                    hour1=0
                    hour2=0
                    hour3=0
                    hour4=0
                    hour5=0
                    hour6=0
                    hour0_4=[hour0,hour1,hour2,hour3,hour4,hour5,hour6]
                    random.shuffle(hour0_4)
                    for p in range(7):
                        tv.append(hour0_4[p])
                    i+=7
                while i%24<13 and i%24>6:
                    hour0=math.floor(random.uniform(0,2))
                    hour1=0
                    hour2=0
                    hour3=0
                    hour4=0
                    hour5=0
                    hour0_4=[hour0,hour1,hour2,hour3,hour4,hour5]
                    i+=6
                    for p in range(6):
                        tv.append(hour0_4[p])
                while i%24<18 and i%24>12:
                    hour0=0
                    hour1=1
                    hour2=0
                    hour3=math.floor(random.uniform(0,2))
                    hour4=0
                    hour0_4=[hour0,hour1,hour2,hour3,hour4]
                    random.shuffle(hour0_4)
                    i+=5
                    for p in range(5):
                        tv.append(hour0_4[p])
                while i%24<22 and i%24>17:
                    hour0=1
                    hour1=1
                    hour2=1
                    hour3=math.floor(random.uniform(0,2))
                    hour0_4=[hour0,hour1,hour2,hour3]
                    random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        tv.append(hour0_4[p])
                while i%24<24 and i%24>21:
                    hour0=0
                    hour1=0
                    hour0_4=[hour0,hour1]
                    i+=2
                    for p in range(2):
                        tv.append(hour0_4[p])
            else:
                while i%24<7:
                    hour0=0
                    hour1=0
                    hour2=0
                    hour3=0
                    hour4=0
                    hour5=0
                    hour6=0
                    hour0_4=[hour0,hour1,hour2,hour3,hour4,hour5,hour6]
                    random.shuffle(hour0_4)
                    for p in range(7):
                        tv.append(hour0_4[p])
                    i+=7
                while i%24<13 and i%24>6:
                    hour0=math.floor(random.uniform(0,2))
                    hour1=0
                    hour2=1
                    hour3=0
                    hour4=0
                    hour5=math.floor(random.uniform(0,2))
                    hour0_4=[hour0,hour1,hour2,hour3,hour4,hour5]
                    i+=6
                    for p in range(6):
                        tv.append(hour0_4[p])
                while i%24<18 and i%24>12:
                    hour0=0
                    hour1=1
                    hour2=0
                    hour3=math.floor(random.uniform(0,2))
                    hour4=1
                    hour0_4=[hour0,hour1,hour2,hour3,hour4]
                    random.shuffle(hour0_4)
                    i+=5
                    for p in range(5):
                        tv.append(hour0_4[p])
                while i%24<22 and i%24>17:
                    hour0=1
                    hour1=1
                    hour2=1
                    hour3=math.floor(random.uniform(0,2))
                    hour0_4=[hour0,hour1,hour2,hour3]
                    random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        tv.append(hour0_4[p])
                while i%24<24 and i%24>21:
                    hour0=0
                    hour1=0
                    hour0_4=[hour0,hour1]
                    i+=2
                    for p in range(2):
                        tv.append(hour0_4[p])
                            
        if iteration ==0:
            for k in range (0,8760):
                l_tv.append(tv[k])
        else:
            for k in range (0,8760):
                l_tv[k]=l_tv[k]+tv[k]
                            
    l_tv = [i * 0.05 for i in l_tv]
                            
    for iteration in range (int(s+m+2*l)):
        socket = []
        i=0
        while i<8760:
            if i%168<24 or i%168>71:
                while i%24<7:
                    hour0=0
                    hour1=0
                    hour2=0
                    hour3=0
                    hour4=0
                    hour5=0
                    hour6=0
                    hour0_4=[hour0,hour1,hour2,hour3,hour4,hour5,hour6]
                    random.shuffle(hour0_4)
                    for p in range(7):
                        socket.append(hour0_4[p])
                    i+=7
                while i%24<13 and i%24>6:
                    hour0=0
                    hour1=0.007
                    hour2=0.007
                    hour3=0
                    hour4=0
                    hour5=0
                    hour0_4=[hour0,hour1,hour2,hour3,hour4,hour5]
                    i+=6
                    for p in range(6):
                        socket.append(hour0_4[p])
                while i%24<18 and i%24>12:
                    hour0=0
                    hour1=0
                    hour2=0
                    hour3=0
                    hour4=0
                    hour0_4=[hour0,hour1,hour2,hour3,hour4]
                    random.shuffle(hour0_4)
                    i+=5
                    for p in range(5):
                        socket.append(hour0_4[p])
                while i%24<22 and i%24>17:
                    hour0=0
                    hour1=0.007
                    hour2=0.007
                    hour3=math.floor(random.uniform(0,2))*0.007
                    hour0_4=[hour0,hour1,hour2,hour3]
                    random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        socket.append(hour0_4[p])
                while i%24<24 and i%24>21:
                    hour0=0
                    hour1=0
                    hour0_4=[hour0,hour1]
                    i+=2
                    for p in range(2):
                        socket.append(hour0_4[p])
            else:
                while i%24<7:
                    hour0=0
                    hour1=0
                    hour2=0
                    hour3=0
                    hour4=0
                    hour5=0
                    hour6=0
                    hour0_4=[hour0,hour1,hour2,hour3,hour4,hour5,hour6]
                    random.shuffle(hour0_4)
                    for p in range(7):
                        socket.append(hour0_4[p])
                    i+=7
                while i%24<13 and i%24>6:
                    hour0=math.floor(random.uniform(0,2))*0.1
                    hour1=0
                    hour2=1*0.007
                    hour3=1*0.007
                    hour4=0
                    hour5=math.floor(random.uniform(0,2))*0.007
                    hour0_4=[hour0,hour1,hour2,hour3,hour4,hour5]
                    i+=6
                    for p in range(6):
                        socket.append(hour0_4[p])
                while i%24<18 and i%24>12:
                    hour0=0
                    hour1=0
                    hour2=0
                    hour3=0
                    hour4=0
                    hour0_4=[hour0,hour1,hour2,hour3,hour4]
                    random.shuffle(hour0_4)
                    i+=5
                    for p in range(5):
                        socket.append(hour0_4[p])
                while i%24<22 and i%24>17:
                    hour0=1*0.007
                    hour1=1*0.007
                    hour2=0
                    hour3=math.floor(random.uniform(0,2))*0.007
                    hour0_4=[hour0,hour1,hour2,hour3]
                    random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        socket.append(hour0_4[p])
                while i%24<24 and i%24>21:
                    hour0=0
                    hour1=0
                    hour0_4=[hour0,hour1]
                    i+=2
                    for p in range(2):
                        socket.append(hour0_4[p])
                            
        if iteration ==0:
            for k in range (0,8760):
                l_socket.append(socket[k])
        else:
            for k in range (0,8760):
                l_socket[k]=l_socket[k]+socket[k]
        
    fridge=array.array('d',[])
    i=0
    while i<8760:
        if i%2==0:
            fridge.append(0.1)
        else:
            fridge.append(random.uniform(0.008,0.012))
        i+=1                            
    fridge = [i * l for i in fridge]
    
    for iteration in range (healthcare*2):
        healthfan = []
        i=0
        while i<8760:
            if i%168<24 or i%168>71:
                while i%24<9:
                    healthfan.append(0)
                    i+=1
                while i%24>8 and i%24<13:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    for p in range(4):
                        healthfan.append(hour0_4[p]) 
                    i+=4
                while i%24<17 and i%24>12:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        healthfan.append(hour0_4[p])  
                while i%24<21 and i%24>16:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        healthfan.append(hour0_4[p])   
                while i%24<24 and i%24>20 :
                    healthfan.append(0)
                    i+=1
            else:
                while i%24<9:
                    healthfan.append(0)
                    i+=1
                while i%24>8 and i%24<13:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        healthfan.append(hour0_4[p]) 
                    i+=4
                while i%24<17 and i%24>12:
                    hour0=0
                    hour1=0
                    hour2=0
                    hour3=0
                    hour0_4=[hour0,hour1,hour2,hour3]
                    random.shuffle(hour0_4)        
                    i+=4
                    for p in range(4):
                        healthfan.append(hour0_4[p])  
                while i%24<21 and i%24>16:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=4
                    for p in range(4):
                        healthfan.append(hour0_4[p])  
                while i%24<24 and i%24>20:
                    healthfan.append(0)
                    i+=1
        if iteration ==0:
            for k in range (0,8760):
                l_healthfan.append(healthfan[k])
        else:
            for k in range (0,8760):
                l_healthfan[k]=l_healthfan[k]+healthfan[k]
            
    l_healthfan = [i * 0.075 for i in l_healthfan]
    
    for iteration in range (healthcare*2):
        healthlight = []
        i=0
        while i<8760:
            if i%168<24 or i%168>71:
                while i%24<9:
                    healthlight.append(0)
                    i+=1
                while i%24>8 and i%24<13:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    for p in range(4):
                        healthlight.append(hour0_4[p]) 
                    i+=4
                while i%24<17 and i%24>12:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        healthlight.append(hour0_4[p])  
                while i%24<21 and i%24>16:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        healthlight.append(hour0_4[p])   
                while i%24<24 and i%24>20 :
                    healthlight.append(0)
                    i+=1
            else:
                while i%24<9:
                    healthlight.append(0)
                    i+=1
                while i%24>8 and i%24<13:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        healthlight.append(hour0_4[p]) 
                    i+=4
                while i%24<17 and i%24>12:
                    hour0=0
                    hour1=0
                    hour2=0
                    hour3=0
                    hour0_4=[hour0,hour1,hour2,hour3]
                    random.shuffle(hour0_4)        
                    i+=4
                    for p in range(4):
                        healthlight.append(hour0_4[p])  
                while i%24<21 and i%24>16:
                    if hiavg[i]==1:
                        hour0=0
                        hour1=0
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=4
                    for p in range(4):
                        healthlight.append(hour0_4[p])  
                while i%24<24 and i%24>20:
                    healthlight.append(0)
                    i+=1
        if iteration ==0:
            for k in range (0,8760):
                l_healthlight.append(healthlight[k])
        else:
            for k in range (0,8760):
                l_healthlight[k]=l_healthlight[k]+healthlight[k]
            
    l_healthlight = [i * 0.040 for i in l_healthlight]
    
    for iteration in range (school):
        schoolfan = []
        i=0
        while i<8760:
            if i%168<24 or i%168>71:
                while i%24<4: #0-3
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        schoolfan.append(hour0_4[p]) 
                    i+=4
                while i%24<8 and i%24>3:     #4-7
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        schoolfan.append(hour0_4[p])
                    i+=4  
                while i%24<12 and i%24>7:       #8-11
                    if hiavg[i]==1:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        schoolfan.append(hour0_4[p])  
                while i%24<16 and i%24>11:            #12-15
                    if hiavg[i]==1:
                        hour0=1
                        hour1=math.floor(random.uniform(0,2))
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=4             
                    for p in range(4):
                        schoolfan.append(hour0_4[p])  
                while i%24<20 and i%24>15:                 #16-19
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=4      
                    for p in range(4):
                        schoolfan.append(hour0_4[p])  
                while i%24<24 and i%24>19:                #20-23
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=4
                    for p in range(4):
                        schoolfan.append(hour0_4[p]) 
            else:  
                schoolfan.append(0) 
                i+=1
                
        if iteration ==0:
            for k in range (0,8760):
                l_schoolfan.append(schoolfan[k])
        else:
            for k in range (0,8760):
                l_schoolfan[k]=l_schoolfan[k]+schoolfan[k]
            
    l_schoolfan = [i * 0.075 for i in l_schoolfan]
        
    for iteration in range (school):
        schoollight = []
        i=0
        while i<8760:
            if i%168<24 or i%168>71:
                while i%24<4:                  #0-3
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        schoollight.append(hour0_4[p]) 
                    i+=4
                while i%24<8 and i%24>3:     #4-7
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    for p in range(4):
                        schoollight.append(hour0_4[p])
                    i+=4  
                while i%24<12 and i%24>7:       #8-11
                    if hiavg[i]==1:
                        hour0=1
                        hour1=1
                        hour2=math.floor(random.uniform(0,2))
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=1
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=math.floor(random.uniform(0,2))
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4
                    for p in range(4):
                        schoollight.append(hour0_4[p])  
                while i%24<16 and i%24>11:            #12-15
                    if hiavg[i]==1:
                        hour0=1
                        hour1=math.floor(random.uniform(0,2))
                        hour2=1
                        hour3=1
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]==2:
                        hour0=1
                        hour1=1
                        hour2=0
                        hour3=math.floor(random.uniform(0,2))
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    if hiavg[i]>2:
                        hour0=0
                        hour1=math.floor(random.uniform(0,2))
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                        random.shuffle(hour0_4)
                    i+=4            
                    for p in range(4):
                        schoollight.append(hour0_4[p])  
                while i%24<20 and i%24>15:                 #16-19
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=4    
                    for p in range(4):
                        schoollight.append(hour0_4[p])  
                while i%24<24 and i%24>19:                #20-23
                    if hiavg[i]<6:
                        hour0=0
                        hour1=0
                        hour2=0
                        hour3=0
                        hour0_4=[hour0,hour1,hour2,hour3]
                    i+=4
                    for p in range(4):
                        schoollight.append(hour0_4[p]) 
            else:  
                schoollight.append(0) 
                i+=1 
        if iteration ==0:
            for k in range (0,8760):
                l_schoollight.append(schoollight[k])
        else:
            for k in range (0,8760):
                l_schoollight[k]=l_schoollight[k]+schoollight[k]
            
    l_schoollight = [i * 0.040 for i in l_schoollight]
        
    
    if (healthcare == 0):
        l_healthlight = [0]*8760
        l_healthfan = [0]*8760
        
    if (school == 0):
        l_schoollight = [0]*8760
        l_schoolfan = [0]*8760
    
    if (l == 0 and m == 0):
        l_tv = [0]*8760

    load = [sum(x) for x in zip(l_fan,l_light,l_bulb,l_tv,l_socket,fridge,l_healthlight,l_healthfan,l_schoolfan,l_schoollight)]
    
    if year>0: #al_fan,l_light,l_bulb,l_tv,l_socket,fridge,l_healthlight,l_healthfan,l_schoolfan,l_schoollightnd year<16:
        load = [x+z for x,z in zip(load_inc,load)]
    
    load_tot = load_tot + load
    
    data = [(l_fan[i],l_light[i],l_bulb[i],l_tv[i],l_socket[i],fridge[i],l_healthlight[i],l_healthfan[i],l_schoolfan[i],l_schoollight[i],load[i]) for i in range (0,8760)]
    df = pd.DataFrame(data = data,columns =['fan','light','bulb','tv','socket','fridge','healthcare fan','healthcare light','school fan','school light','total load'])
    
    df.to_csv('load_madanpur_'+ str(year) +'.csv',index=False,encoding='utf-8')
    
    if year<16:
        app_inc = int(random.uniform(4,7))
        house_inc = 10 - app_inc

        if house_inc==4:
            h4=int(random.uniform(1,5))
            if h4==1 or h4==2 or h4==3:
                s=s+1
            elif h4==4:
                s=s+2
        if house_inc==5:
            h5=int(random.uniform(1,5))
            if h5==1 or h5==2 or h5==3:
                s=s+2
            elif h5==4:
                m=m+1
        if house_inc==6:
            h5=int(random.uniform(1,5))
            if h5==1 or h5==2 or h5==3:
                m=m+1
                s=s+1
            elif h5==4:
                l=l+1

        if app_inc==4:
            inc = random.uniform(3,5)
        if app_inc==5:
            inc = random.uniform(4,6)
        if app_inc==6:
            inc = random.uniform(5,7)

        print ('appliance increase = ',inc)
         
    load_inc = []
    load_inc = [i * (inc/100) for i in load]

# %%
data = [(load_tot[i]) for i in range (0,175200)]
df = pd.DataFrame(data = data,columns =['load'])
df.to_csv('load_total_madanpur.csv',index=False,encoding='utf-8')
